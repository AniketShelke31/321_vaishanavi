# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
df1=pd.read_csv("drive/My Drive/EDS/EmpInfo.csv")
df1
# Out:
#        EMPID  Gender                    JobRole MaritalStatus         DOB
# 0     E00001  Female            Sales Executive        Single  12-02-1987
# 1     E00002    Male         Research Scientist       Married  15-11-1982
# 2     E00003    Male      Laboratory Technician        Single  22-02-1986
# 3     E00004  Female         Research Scientist       Married  25-05-1977
# 4     E00005    Male      Laboratory Technician       Married  04-04-1995
# ...      ...     ...                        ...           ...         ...
# 1053  E01054    Male         Research Scientist       Married  02-03-1993
# 1054  E01055    Male  Healthcare Representative      Divorced  19-12-1982
# 1055  E01056    Male          Research Director      Divorced  08-04-1969
# 1056  E01057    Male       Sales Representative       Married  30-04-1972
# 1057  E01058  Female            Sales Executive        Single  11-09-1978
#
# [1058 rows x 5 columns]

# %%
 df2=pd.read_csv("drive/My Drive/EDS/EmpSalDetails.csv")
 df2
# Out:
#        EMPID    EducationField  Salary ($)  YearsAtCompany
# 0     E00001     Life Sciences       19479               6
# 1     E00002     Life Sciences       24907              10
# 2     E00003             Other        2396               0
# 3     E00004     Life Sciences       23159               8
# 4     E00005           Medical       16632               2
# ...      ...               ...         ...             ...
# 1053  E01054     Life Sciences        2721              12
# 1054  E01055     Life Sciences       20948               8
# 1055  E01056           Medical       11929              14
# 1056  E01057  Technical Degree       15747               3
# 1057  E01058  Technical Degree       17485               5
#
# [1058 rows x 4 columns]

# %% [markdown]
# # 2. merge two dadata frames'

# %%
finaldf=pd.merge(df1,df2,on='EMPID')
finaldf
# Out:
#        EMPID  Gender                    JobRole MaritalStatus         DOB  \
# 0     E00001  Female            Sales Executive        Single  12-02-1987
# 1     E00002    Male         Research Scientist       Married  15-11-1982
# 2     E00003    Male      Laboratory Technician        Single  22-02-1986
# 3     E00004  Female         Research Scientist       Married  25-05-1977
# 4     E00005    Male      Laboratory Technician       Married  04-04-1995
# ...      ...     ...                        ...           ...         ...
# 1053  E01054    Male         Research Scientist       Married  02-03-1993
# 1054  E01055    Male  Healthcare Representative      Divorced  19-12-1982
# 1055  E01056    Male          Research Director      Divorced  08-04-1969
# 1056  E01057    Male       Sales Representative       Married  30-04-1972
# 1057  E01058  Female            Sales Executive        Single  11-09-1978
#
#         EducationField  Salary ($)  YearsAtCompany
# ...

# %%
finaldf.sort_values('Salary ($)')
# Out:
#       EMPID  Gender                    JobRole MaritalStatus         DOB  \
# 28   E00029  Female  Healthcare Representative       Married  17-10-1988
# 543  E00544    Male      Laboratory Technician        Single  03-08-1988
# 459  E00460  Female  Healthcare Representative        Single  26-12-1972
# 473  E00474    Male          Research Director      Divorced  26-03-1971
# 178  E00179  Female            Sales Executive      Divorced  22-05-1976
# ..      ...     ...                        ...           ...         ...
# 386  E00387  Female      Laboratory Technician      Divorced  01-02-1992
# 859  E00860  Female         Research Scientist       Married  19-05-1985
# 107  E00108    Male            Sales Executive        Single  24-05-1968
# 808  E00809  Female         Research Scientist      Divorced  28-12-1966
# 513  E00514    Male         Research Scientist        Single  03-01-1994
#
#     EducationField  Salary ($)  YearsAtCompany
# ...

# %%
finaldf.sort_values('Salary ($)',ascending=False)
# Out:
#       EMPID  Gender                    JobRole MaritalStatus         DOB  \
# 513  E00514    Male         Research Scientist        Single  03-01-1994
# 808  E00809  Female         Research Scientist      Divorced  28-12-1966
# 107  E00108    Male            Sales Executive        Single  24-05-1968
# 859  E00860  Female         Research Scientist       Married  19-05-1985
# 386  E00387  Female      Laboratory Technician      Divorced  01-02-1992
# ..      ...     ...                        ...           ...         ...
# 178  E00179  Female            Sales Executive      Divorced  22-05-1976
# 473  E00474    Male          Research Director      Divorced  26-03-1971
# 459  E00460  Female  Healthcare Representative        Single  26-12-1972
# 543  E00544    Male      Laboratory Technician        Single  03-08-1988
# 28   E00029  Female  Healthcare Representative       Married  17-10-1988
#
#     EducationField  Salary ($)  YearsAtCompany
# ...

# %%
finaldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1058 entries, 0 to 1057
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   EMPID           1058 non-null   object
#  1   Gender          1058 non-null   object
#  2   JobRole         1058 non-null   object
#  3   MaritalStatus   1058 non-null   object
#  4   DOB             1058 non-null   object
#  5   EducationField  1058 non-null   object
#  6   Salary ($)      1058 non-null   int64
#  7   YearsAtCompany  1058 non-null   int64
# dtypes: int64(2), object(6)
# memory usage: 74.4+ KB

# %%
finaldf['DOB']=pd.to_datetime(finaldf['DOB'])
# Out:
# <ipython-input-10-cb11152a730d>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   finaldf['DOB']=pd.to_datetime(finaldf['DOB'])

# %%
from datetime import date
def age_cal(birthdate):
  today = date.today()
  age = today.year - birthdate.year - ((today.month, today.day) < (birthdate.month, birthdate.day))
  return age

# %%
finaldf['Age'] = finaldf['DOB'].apply(age_cal)

# %%
finaldf
# Out:
#        EMPID  Gender                    JobRole MaritalStatus        DOB  \
# 0     E00001  Female            Sales Executive        Single 1987-12-02
# 1     E00002    Male         Research Scientist       Married 1982-11-15
# 2     E00003    Male      Laboratory Technician        Single 1986-02-22
# 3     E00004  Female         Research Scientist       Married 1977-05-25
# 4     E00005    Male      Laboratory Technician       Married 1995-04-04
# ...      ...     ...                        ...           ...        ...
# 1053  E01054    Male         Research Scientist       Married 1993-02-03
# 1054  E01055    Male  Healthcare Representative      Divorced 1982-12-19
# 1055  E01056    Male          Research Director      Divorced 1969-08-04
# 1056  E01057    Male       Sales Representative       Married 1972-04-30
# 1057  E01058  Female            Sales Executive        Single 1978-11-09
#
#         EducationField  Salary ($)  YearsAtCompany  Age
# ...

# %%
def sal_calculation(sal):
  today = date.today()
  return sal*82.04
  finaldf['Sal_INR'] = finaldf['Salary ($) '].apply(sal_conversion)

# %%
finaldf
# Out:
#        EMPID  Gender                    JobRole MaritalStatus        DOB  \
# 0     E00001  Female            Sales Executive        Single 1987-12-02
# 1     E00002    Male         Research Scientist       Married 1982-11-15
# 2     E00003    Male      Laboratory Technician        Single 1986-02-22
# 3     E00004  Female         Research Scientist       Married 1977-05-25
# 4     E00005    Male      Laboratory Technician       Married 1995-04-04
# ...      ...     ...                        ...           ...        ...
# 1053  E01054    Male         Research Scientist       Married 1993-02-03
# 1054  E01055    Male  Healthcare Representative      Divorced 1982-12-19
# 1055  E01056    Male          Research Director      Divorced 1969-08-04
# 1056  E01057    Male       Sales Representative       Married 1972-04-30
# 1057  E01058  Female            Sales Executive        Single 1978-11-09
#
#         EducationField  Salary ($)  YearsAtCompany  Age
# ...
